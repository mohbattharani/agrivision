# %%
import requests
import json
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
range_url = 'http://0.0.0.0:5000/range_graph'
day_url = 'http://0.0.0.0:5000/day_graph'

# %%
# Get range graph data and plot 
req = '{"start_date":"2020-05-10", "end_date":"2020-06-04"}'
x = requests.post(url, data= req)
dates, trash_count = zip(*json.loads(x.text).items())
trash_count = list(map(int, trash_count)) 

f, ax = plt.subplots(figsize=(15,5))
plt.bar(dates, trash_count)
plt.xticks(dates, [str(i) for i in dates], rotation=30)


plt.tick_params(axis='x', which='major', labelsize=15)
ax.xaxis.set_major_locator(plt.MaxNLocator(int(len(dates))))

plt.tight_layout()

# %%
# Get range graph data and plot 
req = '{"start_date":"2020-05-10", "end_date":"2020-05-31"}'
x = requests.post(url, data= req)
dates, trash_count = ziQp(*json.loads(x.text).items())

f, ax = plt.subplots(figsize=(15,5))
plt.bar(dates, trash_count)
plt.xticks(dates, [str(i) for i in dates], rotation=90)


plt.tick_params(axis='x', which='major', labelsize=15)

plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-e2696ba7b5e8> in <module>
#      10
#      11 plt.tick_params(axis='x', which='major', labelsize=15)
# ---> 12 ax.xaxis.set_major_formatter(plt.MaxNLocator(int(len(dates)/2)))
#      13 plt.tight_layout()
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axis.py in set_major_formatter(self, formatter)
#    1610         """
#    1611         if not isinstance(formatter, mticker.Formatter):
# -> 1612             raise TypeError("formatter argument should be instance of "
#    1613                     "matplotlib.ticker.Formatter")
#    1614         self.isDefault_majfmt = False
#
# TypeError: formatter argument should be instance of matplotlib.ticker.Formatter

# %%
# Out:
# ('2020-05-10',
#  '2020-05-11',
#  '2020-05-12',
#  '2020-05-13',
#  '2020-05-14',
#  '2020-05-15',
#  '2020-05-16',
#  '2020-05-17',
#  '2020-05-18',
#  '2020-05-19',
#  '2020-05-20',
#  '2020-05-21',
#  '2020-05-22',
#  '2020-05-23',
#  '2020-05-24',
#  '2020-05-25',
#  '2020-05-26',
#  '2020-05-27',
#  '2020-05-28')
